# %% [markdown]
# # Specific Test V. Exploring Transformers
#
# > Three different transformer models were used for this test. This notebook contains the results of the CrossFormer model.
#
# **Task:** Use a vision transformer method of your choice to build a robust and efficient model for binary classification or unsupervised anomaly detection on the provided dataset. In the case of unsupervised anomaly detection, train your model to learn the distribution of the provided strong lensing images with no substructure. Please implement your approach in PyTorch or Keras and discuss your strategy.
#
# **Dataset Description:** A set of simulated strong gravitational lensing images with and without substructure.
#
# **Evaluation Metrics:** ROC curve (Receiver Operating Characteristic curve) and AUC score (Area Under the ROC Curve)

# %% [markdown]
# ## Strategy
#
# A CrossFormer model was used for classifying the images in this test. The model was trained for 30 epochs with an initial learning rate of 0.0001 and a batch size of 64. The scheduler used was CosineAnnealingLR with with a minimum learning rate of 0.00001. the criterion used was CrossEntropyLoss
#
# The dataset is split in a 9:1 test-train ratio. The training set is resized to 224*224 image and augmented using ColorJitter, RandomHorizontalFlip and RandomRotation. The test set is only resized and not augmented.

# %% [markdown]
# ## Results
#
# **ROC-AUC Score:** 0.99986
#
# **Training Curve:**
#
# ![Training Curve](../results/test-5-crossformer-training-plot.png)
#
# **ROC Curve:**
#
# ![ROC Curve](../results/test-5-crossformer-roc-plot.png)

# %% [markdown]
# ## Importing Library

# %%
# !pip install vit-pytorch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: vit-pytorch in /home/gautham/.local/lib/python3.10/site-packages (1.0.2)
# Requirement already satisfied: torch>=1.10 in /home/gautham/.local/lib/python3.10/site-packages (from vit-pytorch) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /home/gautham/.local/lib/python3.10/site-packages (from vit-pytorch) (0.14.1+cu116)
# Requirement already satisfied: einops>=0.6.0 in /home/gautham/.local/lib/python3.10/site-packages (from vit-pytorch) (0.6.0)
# Requirement already satisfied: typing-extensions in /home/gautham/.local/lib/python3.10/site-packages (from torch>=1.10->vit-pytorch) (4.3.0)
# Requirement already satisfied: requests in /home/gautham/.local/lib/python3.10/site-packages (from torchvision->vit-pytorch) (2.28.2)
# Requirement already satisfied: numpy in /home/gautham/.local/lib/python3.10/site-packages (from torchvision->vit-pytorch) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/gautham/.local/lib/python3.10/site-packages (from torchvision->vit-pytorch) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gautham/.local/lib/python3.10/site-packages (from requests->torchvision->vit-pytorch) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gautham/.local/lib/python3.10/site-packages (from requests->torchvision->vit-pytorch) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/gautham/.local/lib/python3.10/site-packages (from requests->torchvision->vit-pytorch) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gautham/.local/lib/python3.10/site-packages (from requests->torchvision->vit-pytorch) (2022.12.7)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from vit_pytorch.crossformer import CrossFormer
import numpy as np
import pandas as pd
import os
from PIL import Image
from tqdm import tqdm
import seaborn as sns

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Loading Data

# %%
base_dir = '../datasets/test5/lenses'

train_df = pd.DataFrame(columns = ['path', 'label'])

label_map = {'no_sub':0, 'sub':1}
val_label_map = {0:'no_sub', 1:'sub'}

for i in label_map.keys():
    entries = [os.path.join(base_dir, i, j) for j in os.listdir(os.path.join(base_dir, i))]
    temp_df = pd.DataFrame({'path':entries, 'label':i})
    train_df = pd.concat([train_df, temp_df], ignore_index=True)

train_df.head()
# Out:
#                                                 path   label
# 0  ../datasets/test5/lenses/no_sub/image_17478751...  no_sub
# 1  ../datasets/test5/lenses/no_sub/image_58501840...  no_sub
# 2  ../datasets/test5/lenses/no_sub/image_20642528...  no_sub
# 3  ../datasets/test5/lenses/no_sub/image_22438675...  no_sub
# 4  ../datasets/test5/lenses/no_sub/image_27048203...  no_sub

# %%
train_df, test_df = train_test_split(train_df, test_size=0.1, random_state=42, stratify=train_df['label'])

print(f"Train split:\n{train_df['label'].value_counts()}\n")
print(f"Test split:\n{test_df['label'].value_counts()}")
# Out:
# Train split:
# sub       4500
# no_sub    4500
# Name: label, dtype: int64
#
# Test split:
# sub       500
# no_sub    500
# Name: label, dtype: int64

# %%
class Dataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.iloc[idx]['path']
        img = Image.open(img_path).convert('RGB')
        
        if self.transform:
            img = self.transform(img)

        label = self.df.iloc[idx]['label']
        label = label_map[label]
        
        return img, label

# %%
train_transforms = transforms.Compose([
    transforms.Resize(224),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.RandomRotation(180),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])

test_transforms = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor()
])

train_dataset = Dataset(train_df, transform=train_transforms)
test_dataset = Dataset(test_df, transform=test_transforms)

batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

# %%
def show_batch(images, labels, class_map):
    fig, ax = plt.subplots(3, 3, figsize=(6, 6))
    for i in range(3):
        for j in range(3):
            image = images[i*3 + j]
            label = labels[i*3 + j].item()
            ax[i][j].imshow(image.permute(1, 2, 0))
            title = class_map[label]
            ax[i][j].set_title(title)
            ax[i][j].axis('off')
            ax[i][j].title.set_fontsize(10)

    plt.show()

images, labels = next(iter(train_loader))
show_batch(images, labels, val_label_map)

# %% [markdown]
# ## Defining Model

# %%
model = CrossFormer(
    num_classes = 2,                
    dim = (64, 128, 256, 512),         
    depth = (2, 2, 8, 2),              
    global_window_size = (8, 4, 2, 1), 
    local_window_size = 7,             
).to(device)

# %% [markdown]
# ## Hyper-parameters and Training

# %%
def train(model, epochs, optimizer, criterion, scheduler, device, trainloader, testloader):

    train_losses = []
    train_acc = []
    test_losses = []
    test_acc = []
        
    for i in range(epochs):
        running_loss = 0.0
        running_correct = 0
        total = 0
        best_acc = 0.0
        
        print(f"Epoch: {i + 1}")
        
        for images, targets in tqdm(trainloader, desc= "Train\t"):
            
            images, targets = images.to(device), targets.to(device)
            optimizer.zero_grad()
            output = model(images)
            loss = criterion(output, targets)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pred = torch.argmax(output, dim=1)
        
            running_correct += (pred == targets).sum().item()
            total += targets.size(0)

        scheduler.step()
        
        train_losses.append(running_loss / len(trainloader))
        train_acc.append(running_correct / total)

        running_val_loss = 0.0
        correct = 0
        total = 0
        
        with torch.no_grad():

            for images, targets in tqdm(testloader, desc= "Test\t"):
                images, targets = images.to(device), targets.to(device)

                output = model(images)
                preds = torch.argmax(output, dim=1)

                correct += (preds == targets).sum().item()
                running_val_loss += criterion(output, targets).item()
                total += targets.size(0)

            acc = correct / total
            test_acc.append(acc)
            test_losses.append(running_val_loss / len(testloader))

        if test_acc[-1] > best_acc:
            best_acc = test_acc[-1]
            torch.save(model.state_dict(), '../models/test-5-regionvit-model.pth') 

        print(f"Train Loss: {train_losses[-1]:.3f}, Train Acc: {train_acc[-1]:.3f}, Test Loss: {test_losses[-1]:.3f}, Test Acc: {test_acc[-1]:.3f}\n")

    return train_losses, train_acc, test_losses, test_acc, best_acc

# %%
epochs = 30
lr = 0.0001
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=lr*0.01)

# %%
train_losses, train_acc, test_losses, test_acc, best_acc = train(model, epochs, optimizer, loss_function, scheduler, device, train_loader, test_loader)
# Out:
# Epoch: 1
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.70it/s]
# Train Loss: 0.823, Train Acc: 0.507, Test Loss: 0.700, Test Acc: 0.500
#
# Epoch: 2
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.70it/s]
# Train Loss: 0.725, Train Acc: 0.498, Test Loss: 0.693, Test Acc: 0.500
#
# Epoch: 3
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.72it/s]
# Train Loss: 0.706, Train Acc: 0.509, Test Loss: 0.696, Test Acc: 0.500
#
# Epoch: 4
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.72it/s]
# Train Loss: 0.693, Train Acc: 0.530, Test Loss: 0.686, Test Acc: 0.512
#
# Epoch: 5
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.65it/s]
# Train Loss: 0.686, Train Acc: 0.557, Test Loss: 0.692, Test Acc: 0.514
#
# Epoch: 6
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.65it/s]
# Train Loss: 0.654, Train Acc: 0.605, Test Loss: 0.599, Test Acc: 0.664
#
# Epoch: 7
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.67it/s]
# Train Loss: 0.615, Train Acc: 0.664, Test Loss: 0.542, Test Acc: 0.749
#
# Epoch: 8
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.64it/s]
# Train Loss: 0.565, Train Acc: 0.695, Test Loss: 0.606, Test Acc: 0.597
#
# Epoch: 9
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:05<00:00,  2.88it/s]
# Train Loss: 0.472, Train Acc: 0.748, Test Loss: 0.434, Test Acc: 0.781
#
# Epoch: 10
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.34it/s]
# Train Loss: 0.397, Train Acc: 0.800, Test Loss: 0.306, Test Acc: 0.840
#
# Epoch: 11
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.61it/s]
# Train Loss: 0.346, Train Acc: 0.824, Test Loss: 0.262, Test Acc: 0.859
#
# Epoch: 12
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.64it/s]
# Train Loss: 0.267, Train Acc: 0.876, Test Loss: 0.213, Test Acc: 0.907
#
# Epoch: 13
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.54it/s]
# Train Loss: 0.202, Train Acc: 0.904, Test Loss: 0.220, Test Acc: 0.900
#
# Epoch: 14
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.53it/s]
# Train Loss: 0.180, Train Acc: 0.917, Test Loss: 0.121, Test Acc: 0.956
#
# Epoch: 15
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.60it/s]
# Train Loss: 0.159, Train Acc: 0.929, Test Loss: 0.102, Test Acc: 0.961
#
# Epoch: 16
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.45it/s]
# Train Loss: 0.113, Train Acc: 0.951, Test Loss: 0.248, Test Acc: 0.897
#
# Epoch: 17
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.71it/s]
# Train Loss: 0.119, Train Acc: 0.949, Test Loss: 0.114, Test Acc: 0.954
#
# Epoch: 18
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.70it/s]
# Train Loss: 0.101, Train Acc: 0.958, Test Loss: 0.075, Test Acc: 0.964
#
# Epoch: 19
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.70it/s]
# Train Loss: 0.089, Train Acc: 0.963, Test Loss: 0.064, Test Acc: 0.977
#
# Epoch: 20
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.72it/s]
# Train Loss: 0.079, Train Acc: 0.968, Test Loss: 0.059, Test Acc: 0.974
#
# Epoch: 21
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.70it/s]
# Train Loss: 0.070, Train Acc: 0.971, Test Loss: 0.087, Test Acc: 0.960
#
# Epoch: 22
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.64it/s]
# Train Loss: 0.062, Train Acc: 0.974, Test Loss: 0.061, Test Acc: 0.974
#
# Epoch: 23
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.64it/s]
# Train Loss: 0.055, Train Acc: 0.978, Test Loss: 0.058, Test Acc: 0.973
#
# Epoch: 24
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.73it/s]
# Train Loss: 0.051, Train Acc: 0.981, Test Loss: 0.073, Test Acc: 0.961
#
# Epoch: 25
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.71it/s]
# Train Loss: 0.045, Train Acc: 0.983, Test Loss: 0.040, Test Acc: 0.982
#
# Epoch: 26
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.68it/s]
# Train Loss: 0.041, Train Acc: 0.984, Test Loss: 0.030, Test Acc: 0.990
#
# Epoch: 27
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.48it/s]
# Train Loss: 0.039, Train Acc: 0.985, Test Loss: 0.045, Test Acc: 0.978
#
# Epoch: 28
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.72it/s]
# Train Loss: 0.034, Train Acc: 0.987, Test Loss: 0.018, Test Acc: 0.996
#
# Epoch: 29
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.68it/s]
# Train Loss: 0.034, Train Acc: 0.988, Test Loss: 0.021, Test Acc: 0.995
#
# Epoch: 30
# Train	: 100%|██████████| 141/141 [01:56<00:00,  1.21it/s]
# Test	: 100%|██████████| 16/16 [00:04<00:00,  3.73it/s]
# Train Loss: 0.031, Train Acc: 0.988, Test Loss: 0.025, Test Acc: 0.988

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Testing loss')
plt.legend(frameon=False)

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training accuracy')
plt.plot(test_acc, label='Testing accuracy')
plt.legend(frameon=False)

# %% [markdown]
# ## Testing

# %% [markdown]
# The best model is loaded for testing and the results are plotted.

# %%
model = CrossFormer(
    num_classes = 2,                
    dim = (64, 128, 256, 512),         
    depth = (2, 2, 8, 2),              
    global_window_size = (8, 4, 2, 1), 
    local_window_size = 7,             
).to(device)
model.load_state_dict(torch.load('../models/test-5-regionvit-model.pth'))
# Out:
# <All keys matched successfully>

# %%
y_true = []
y_pred_class = []
y_pred_prob = []

with torch.no_grad():
    for images, targets in tqdm(test_loader):
        images, targets = images.to(device), targets.to(device)
        output = model(images)
        preds = torch.argmax(output, dim=1)
        y_true.extend(targets.cpu().numpy())
        y_pred_class.extend(preds.cpu().numpy())
        y_pred_prob.extend(output.cpu().numpy())
# Out:
# 100%|██████████| 16/16 [00:04<00:00,  3.62it/s]

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report, auc

print(classification_report(y_true, y_pred_class, target_names=label_map.keys()))
# Out:
#               precision    recall  f1-score   support
#
#       no_sub       0.98      1.00      0.99       500
#          sub       1.00      0.98      0.99       500
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
conf_matrix = confusion_matrix(y_true, y_pred_class)
plt.figure(figsize=(7, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=label_map.keys(), yticklabels=label_map.keys())
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
print(f"ROC-AUC Score: {roc_auc_score(y_true, np.array(y_pred_prob)[:,1], multi_class='ovr')}")
# Out:
# ROC-AUC Score: 0.99986

# %%
y_true_dummies = pd.get_dummies(y_true).values

auc_scores = {}
for i in range(2):
    fpr_i, tpr_i, thresholds_i = roc_curve(y_true_dummies[:, i], np.array(y_pred_prob)[:, i])
    auc_score = auc(fpr_i, tpr_i)
    print(f"{(val_label_map[i]).ljust(8)} ROC-AUC: {auc_score}")
    auc_scores[val_label_map[i]] = auc_score
    plt.plot(fpr_i, tpr_i, label=f"{(val_label_map[i]).ljust(6)} AUC: {auc_score:.4f}")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# no_sub   ROC-AUC: 0.999848
# sub      ROC-AUC: 0.99986
